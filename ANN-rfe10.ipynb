# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import keras
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from keras.callbacks import EarlyStopping
from keras.utils import plot_model

# %%
data = pd.read_csv('rfe_dataset_10.csv')

# %%
X = data.drop('Class', axis = 1)
y = data[['Class']]

# %%
# Podela podataka na trening i test set
X_train, X_test, y_train, y_test = train_test_split(X, y.values.ravel(), test_size=0.2, random_state=42, stratify = y)

# %%
# Kreiranje neuronske mreže
model = keras.Sequential([
    keras.layers.Dense(128, input_dim=X.shape[1], activation='relu', kernel_regularizer=keras.regularizers.l2(l2=0.01)),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(64, activation='relu', kernel_regularizer=keras.regularizers.l2(l2=0.01)),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(16, activation='relu', kernel_regularizer=keras.regularizers.l2(l2=0.01)),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(1, activation='sigmoid')
])

# %%
# Kompajliranje modela
model.compile(loss = keras.losses.BinaryCrossentropy(), optimizer='adam', metrics=['accuracy'])

# %%
callbacks = [EarlyStopping(monitor='val_loss', patience=5)]

# %%
# Obuka modela
history = model.fit(X_train, y_train, epochs=50, batch_size=64, validation_data=(X_test, y_test), callbacks=callbacks)
# Out:
# Epoch 1/50
# 2/2 [==============================] - 1s 156ms/step - loss: 1.9636 - accuracy: 0.5100 - val_loss: 1.9039 - val_accuracy: 0.6923
# Epoch 2/50
# 2/2 [==============================] - 0s 22ms/step - loss: 1.9322 - accuracy: 0.5200 - val_loss: 1.8700 - val_accuracy: 0.6923
# Epoch 3/50
# 2/2 [==============================] - 0s 26ms/step - loss: 1.8974 - accuracy: 0.5900 - val_loss: 1.8379 - val_accuracy: 0.7308
# Epoch 4/50
# 2/2 [==============================] - 0s 22ms/step - loss: 1.8504 - accuracy: 0.5600 - val_loss: 1.8073 - val_accuracy: 0.7692
# Epoch 5/50
# 2/2 [==============================] - 0s 21ms/step - loss: 1.8293 - accuracy: 0.6600 - val_loss: 1.7778 - val_accuracy: 0.7692
# Epoch 6/50
# 2/2 [==============================] - 0s 25ms/step - loss: 1.7826 - accuracy: 0.6500 - val_loss: 1.7484 - val_accuracy: 0.7692
# Epoch 7/50
# 2/2 [==============================] - 0s 21ms/step - loss: 1.7619 - accuracy: 0.6300 - val_loss: 1.7194 - val_accuracy: 0.7692
# Epoch 8/50
# 2/2 [==============================] - 0s 24ms/step - loss: 1.7234 - accuracy: 0.6600 - val_loss: 1.6904 - val_accuracy: 0.7308
# Epoch 9/50
# 2/2 [==============================] - 0s 20ms/step - loss: 1.6993 - accuracy: 0.7300 - val_loss: 1.6623 - val_accuracy: 0.6923
# Epoch 10/50
# 2/2 [==============================] - 0s 23ms/step - loss: 1.6578 - accuracy: 0.7200 - val_loss: 1.6345 - val_accuracy: 0.7308
# Epoch 11/50
# 2/2 [==============================] - 0s 21ms/step - loss: 1.6468 - accuracy: 0.6500 - val_loss: 1.6071 - val_accuracy: 0.7308
# Epoch 12/50
# 2/2 [==============================] - 0s 23ms/step - loss: 1.6011 - accuracy: 0.7300 - val_loss: 1.5803 - val_accuracy: 0.7308
# Epoch 13/50
# 2/2 [==============================] - 0s 26ms/step - loss: 1.5793 - accuracy: 0.7300 - val_loss: 1.5545 - val_accuracy: 0.7308
# Epoch 14/50
# 2/2 [==============================] - 0s 23ms/step - loss: 1.5456 - accuracy: 0.7700 - val_loss: 1.5288 - val_accuracy: 0.7308
# Epoch 15/50
# 2/2 [==============================] - 0s 21ms/step - loss: 1.5176 - accuracy: 0.7700 - val_loss: 1.5036 - val_accuracy: 0.7308
# Epoch 16/50
# 2/2 [==============================] - 0s 20ms/step - loss: 1.5117 - accuracy: 0.7100 - val_loss: 1.4790 - val_accuracy: 0.7308
# Epoch 17/50
# 2/2 [==============================] - 0s 22ms/step - loss: 1.4641 - accuracy: 0.7700 - val_loss: 1.4551 - val_accuracy: 0.7308
# Epoch 18/50
# 2/2 [==============================] - 0s 17ms/step - loss: 1.4587 - accuracy: 0.7600 - val_loss: 1.4311 - val_accuracy: 0.7308
# Epoch 19/50
# 2/2 [==============================] - 0s 21ms/step - loss: 1.4297 - accuracy: 0.7900 - val_loss: 1.4076 - val_accuracy: 0.7308
# Epoch 20/50
# 2/2 [==============================] - 0s 22ms/step - loss: 1.4012 - accuracy: 0.7400 - val_loss: 1.3846 - val_accuracy: 0.7308
# Epoch 21/50
# 2/2 [==============================] - 0s 21ms/step - loss: 1.3887 - accuracy: 0.7800 - val_loss: 1.3620 - val_accuracy: 0.7692
# Epoch 22/50
# 2/2 [==============================] - 0s 22ms/step - loss: 1.3827 - accuracy: 0.7400 - val_loss: 1.3406 - val_accuracy: 0.7692
# Epoch 23/50
# 2/2 [==============================] - 0s 24ms/step - loss: 1.3422 - accuracy: 0.7500 - val_loss: 1.3190 - val_accuracy: 0.7308
# Epoch 24/50
# 2/2 [==============================] - 0s 21ms/step - loss: 1.3260 - accuracy: 0.7400 - val_loss: 1.2971 - val_accuracy: 0.7308
# Epoch 25/50
# 2/2 [==============================] - 0s 25ms/step - loss: 1.3014 - accuracy: 0.7700 - val_loss: 1.2752 - val_accuracy: 0.7308
# Epoch 26/50
# 2/2 [==============================] - 0s 21ms/step - loss: 1.2701 - accuracy: 0.7300 - val_loss: 1.2537 - val_accuracy: 0.7308
# Epoch 27/50
# 2/2 [==============================] - 0s 24ms/step - loss: 1.2522 - accuracy: 0.7900 - val_loss: 1.2334 - val_accuracy: 0.7692
# Epoch 28/50
# 2/2 [==============================] - 0s 20ms/step - loss: 1.2351 - accuracy: 0.7600 - val_loss: 1.2129 - val_accuracy: 0.7692
# Epoch 29/50
# 2/2 [==============================] - 0s 23ms/step - loss: 1.2251 - accuracy: 0.7400 - val_loss: 1.1931 - val_accuracy: 0.7692
# Epoch 30/50
# 2/2 [==============================] - 0s 20ms/step - loss: 1.1957 - accuracy: 0.8000 - val_loss: 1.1730 - val_accuracy: 0.7692
# Epoch 31/50
# 2/2 [==============================] - 0s 24ms/step - loss: 1.1827 - accuracy: 0.7700 - val_loss: 1.1537 - val_accuracy: 0.7692
# Epoch 32/50
# 2/2 [==============================] - 0s 22ms/step - loss: 1.1643 - accuracy: 0.7400 - val_loss: 1.1345 - val_accuracy: 0.7692
# Epoch 33/50
# 2/2 [==============================] - 0s 25ms/step - loss: 1.1494 - accuracy: 0.7900 - val_loss: 1.1167 - val_accuracy: 0.7308
# Epoch 34/50
# 2/2 [==============================] - 0s 21ms/step - loss: 1.1263 - accuracy: 0.7600 - val_loss: 1.0997 - val_accuracy: 0.7308
# Epoch 35/50
# 2/2 [==============================] - 0s 22ms/step - loss: 1.1334 - accuracy: 0.7800 - val_loss: 1.0831 - val_accuracy: 0.7308
# Epoch 36/50
# 2/2 [==============================] - 0s 22ms/step - loss: 1.0827 - accuracy: 0.8200 - val_loss: 1.0665 - val_accuracy: 0.7308
# Epoch 37/50
# 2/2 [==============================] - 0s 22ms/step - loss: 1.0826 - accuracy: 0.8000 - val_loss: 1.0508 - val_accuracy: 0.7308
# Epoch 38/50
# 2/2 [==============================] - 0s 22ms/step - loss: 1.0728 - accuracy: 0.8000 - val_loss: 1.0361 - val_accuracy: 0.7692
# Epoch 39/50
# 2/2 [==============================] - 0s 21ms/step - loss: 1.0282 - accuracy: 0.8400 - val_loss: 1.0222 - val_accuracy: 0.7692
# Epoch 40/50
# 2/2 [==============================] - 0s 21ms/step - loss: 1.0483 - accuracy: 0.8000 - val_loss: 1.0089 - val_accuracy: 0.7692
# Epoch 41/50
# 2/2 [==============================] - 0s 27ms/step - loss: 1.0189 - accuracy: 0.8200 - val_loss: 0.9955 - val_accuracy: 0.7692
# Epoch 42/50
# 2/2 [==============================] - 0s 17ms/step - loss: 1.0052 - accuracy: 0.7900 - val_loss: 0.9818 - val_accuracy: 0.8462
# Epoch 43/50
# 2/2 [==============================] - 0s 28ms/step - loss: 0.9730 - accuracy: 0.8100 - val_loss: 0.9682 - val_accuracy: 0.8462
# Epoch 44/50
# 2/2 [==============================] - 0s 22ms/step - loss: 1.0001 - accuracy: 0.7900 - val_loss: 0.9548 - val_accuracy: 0.8462
# Epoch 45/50
# 2/2 [==============================] - 0s 21ms/step - loss: 0.9509 - accuracy: 0.8200 - val_loss: 0.9412 - val_accuracy: 0.8462
# Epoch 46/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.9450 - accuracy: 0.8400 - val_loss: 0.9286 - val_accuracy: 0.8462
# Epoch 47/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.9336 - accuracy: 0.7900 - val_loss: 0.9162 - val_accuracy: 0.8462
# Epoch 48/50
# 2/2 [==============================] - 0s 19ms/step - loss: 0.9325 - accuracy: 0.8300 - val_loss: 0.9045 - val_accuracy: 0.8462
# Epoch 49/50
# 2/2 [==============================] - 0s 20ms/step - loss: 0.9032 - accuracy: 0.8200 - val_loss: 0.8930 - val_accuracy: 0.8462
# Epoch 50/50
# 2/2 [==============================] - 0s 24ms/step - loss: 0.8996 - accuracy: 0.8200 - val_loss: 0.8823 - val_accuracy: 0.8462

# %%
# Testiranje predikcija
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)
# Out:
# 4/4 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 15ms/step

# %%
threshold = 0.5
y_train_pred_binary = [1 if pred >= threshold else 0 for pred in y_train_pred]
y_test_pred_binary = [1 if pred >= threshold else 0 for pred in y_test_pred]

# %%
accuracy_score(y_train, y_train_pred_binary)
# Out:
# 0.88

# %%
accuracy_score(y_test, y_test_pred_binary)
# Out:
# 0.8461538461538461

# %%
cm_train = confusion_matrix(y_train, y_train_pred_binary)

# %%
sns.heatmap(cm_train, annot=True, cmap='Blues')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.show()

# %%
cm_test = confusion_matrix(y_test, y_test_pred_binary)

# %%
sns.heatmap(cm_test, annot=True, cmap='Blues')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
